# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
df = pd.read_csv('/Users/xinqu/Sandbox/CS498 Applied Machine Learning/HW/HW7/yelp_2k.csv')
df = df[['text', 'stars']]
df.head()
# Out:
#                                                 text  stars
# 0  This car wash sucks.  Paid $40 for the Ultimat...      1
# 1  I was referred to Earnie by friends and since ...      5
# 2  The food is okay, but they have the worst serv...      1
# 3  Opting out from the noise and hustle of Flo's ...      1
# 4  Basically, unlimited steak. If you like steak,...      5

# %% [markdown]
# Part 1

# %%
import re
df['clean_text'] = df.text.apply(lambda x: re.sub('[^a-zA-Z]', ' ', x))
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, 
                             token_pattern = u"(?u)\\b\\w+\\b", stop_words = None, max_features = 100000) 
train_data_features = vectorizer.fit_transform(df['clean_text'])
#vectorizer.transform([df.iloc[0]['text']]).toarray()

# %%
train_data_features.shape
# Out:
# (2000, 12852)

# %%
sum_words = train_data_features.sum(axis = 0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse =True)
words_freq[:20]
# Out:
# [(u'the', 11041),
#  (u'and', 8107),
#  (u'i', 7511),
#  (u'to', 6565),
#  (u'a', 5498),
#  (u'was', 3817),
#  (u'it', 3333),
#  (u'of', 3040),
#  (u'for', 2728),
#  (u'in', 2703),
#  (u'my', 2606),
#  (u'is', 2604),
#  (u'that', 2321),
#  (u'they', 2295),
#  (u'this', 2116),
#  (u'we', 2029),
#  (u'you', 1962),
#  (u'with', 1817),
#  (u't', 1802),
#  (u'on', 1719)]

# %%
words = pd.DataFrame(words_freq, columns = ['word', 'count'])
words['word_rank'] = words['count'].rank(ascending = False)
words.head()
# Out:
#   word  count  word_rank
# 0  the  11041        1.0
# 1  and   8107        2.0
# 2    i   7511        3.0
# 3   to   6565        4.0
# 4    a   5498        5.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(8, 6))
plt.plot(words['word_rank'], words['count'], color='g', linestyle='dashed', marker = 'o',linewidth=2,alpha=0.5)
plt.xlabel('Word Rank')
plt.ylabel('Word count')
plt.title('Word counts vs word rank')
plt.grid()

# %%
stop_words_list_max = words['word'][words['count'] > 250].values.tolist() ##threshold = 250
stop_words_list_max += words['word'][words['count'] <=1].values.tolist()
stop_words_list_max
# Out:
# [u'the',
#  u'and',
#  u'i',
#  u'to',
#  u'a',
#  u'was',
#  u'it',
#  u'of',
#  u'for',
#  u'in',
#  u'my',
#  u'is',
#  u'that',
#  u'they',
#  u'this',
#  u'we',
#  u'you',
#  u'with',
#  u't',
#  u'on',
#  u'not',
#  u'have',
#  u'but',
#  u'had',
#  u'me',
#  u'at',
#  u's',
#  u'so',
#  u'were',
#  u'are',
#  u'be',
#  u'place',
#  u'food',
#  u'there',
#  u'as',
#  u'he',
#  u'if',
#  u'all',
#  u'when',
#  u'out',
#  u'would',
#  u'service',
#  u'get',
#  u'our',
#  u'she',
#  u'back',
#  u'one',
#  u'up',
#  u'time',
#  u'from',
#  u'very',
#  u'an',
#  u'just',
#  u'their',
#  u'here',
#  u'no',
#  u'will',
#  u'great',
#  u'like',
#  u'good',
#  u'go',
#  u'about',
#  u'them',
#  u'or',
#  u'can',
#  u'what',
#  u'your',
#  u'us',
#  u'been',
#  u'do',
#  u'never',
#  u'because',
#  u'only',
#  u'don',
#  u'even',
#  u'after',
#  u'by',
#  u'which',
#  u'did',
#  u'got',
#  u'said',
#  u'more',
#  u'her',
#  u'really',
#  u'told',
#  u'also',
#  u'could',
#  u'some',
#  u'other',
#  u'then',
#  u'went',
#  u've',
#  u'over',
#  u'has',
#  u'well',
#  u'didn',
#  u'again',
#  u'm',
#  u'first',
#  u'best',
#  u'people',
#  u'staff',
#  u'who',
#  u'going',
#  u'came',
#  u'order',
#  u'make',
#  u'any',
#  u'know',
#  u'ordered',
#  u'day',
#  u'ever',
#  u'restaurant',
#  u'how',
#  u'asked',
#  u'off',
#  u'customer',
#  u'am',
#  u'always',
#  u'too',
#  u'come',
#  u'his',
#  u'take',
#  u'took',
#  u'than',
#  u'minutes',
#  u'made',
#  u'experience',
#  u'before',
#  u'try',
#  u'give',
#  u'love',
#  u'car',
#  u'new',
#  u'gai',
#  u'cussed',
#  u'woods',
#  u'woody',
#  u'snowing',
#  u'scold',
#  u'unanswered',
#  u'lord',
#  u'patying',
#  u'sixer',
#  u'miele',
#  u'hacked',
#  u'gerade',
#  u'stabbed',
#  u'polyacrylamide',
#  u'prize',
#  u'clings',
#  u'piling',
#  u'persisted',
#  u'broadstone',
#  u'nigh',
#  u'errors',
#  u'medically',
#  u'ruthless',
#  u'bonuses',
#  u'roadhouse',
#  u'groupie',
#  u'shocks',
#  u'avery',
#  u'erus',
#  u'chino',
#  u'previews',
#  u'tatum',
#  u'natured',
#  u'poutines',
#  u'learnard',
#  u'oxymoron',
#  u'electricity',
#  u'himmlisch',
#  u'magst',
#  u'scoffed',
#  u'aesthetician',
#  u'geisha',
#  u'accommodation',
#  u'symphony',
#  u'therefore',
#  u'reichhaltig',
#  u'standardized',
#  u'alcoholically',
#  u'inwards',
#  u'intake',
#  u'morally',
#  u'pompadour',
#  u'sweeter',
#  u'concepts',
#  u'zinnias',
#  u'omelets',
#  u'vor',
#  u'couter',
#  u'facade',
#  u'smth',
#  u'cookery',
#  u'hog',
#  u'cutback',
#  u'garments',
#  u'typed',
#  u'coffeeshop',
#  u'cervezas',
#  u'dinosaurs',
#  u'farrrr',
#  u'destined',
#  u'armamnet',
#  u'effective',
#  u'headquarters',
#  u'sickening',
#  u'feedback',
#  u'kochbuch',
#  u'peut',
#  u'partnered',
#  u'bubbles',
#  u'conned',
#  u'lovingly',
#  u'integritythank',
#  u'seasonality',
#  u'fanciest',
#  u'versuchte',
#  u'fig',
#  u'falsch',
#  u'fil',
#  u'songwriter',
#  u'bixi',
#  u'silver',
#  u'ruth',
#  u'horton',
#  u'pleasantries',
#  u'spotless',
#  u'preceded',
#  u'woes',
#  u'spider',
#  u'rt',
#  u'sleepless',
#  u'touts',
#  u'smirk',
#  u'excepting',
#  u'mason',
#  u'cheerfully',
#  u'foundation',
#  u'grapes',
#  u'crowned',
#  u'cadging',
#  u'ministries',
#  u'speedy',
#  u'tempting',
#  u'reserving',
#  u'leaps',
#  u'stripe',
#  u'callous',
#  u'stunnas',
#  u'bacaro',
#  u'millers',
#  u'clarity',
#  u'sherway',
#  u'basketball',
#  u'engagement',
#  u'bitter',
#  u'wisdom',
#  u'finalement',
#  u'positively',
#  u'easys',
#  u'sanderson',
#  u'franizkaner',
#  u'hibachi',
#  u'rusty',
#  u'idle',
#  u'sorbets',
#  u'slicers',
#  u'endure',
#  u'tres',
#  u'willingness',
#  u'shampooed',
#  u'chako',
#  u'zzeeks',
#  u'mangoberry',
#  u'alive',
#  u'wholesome',
#  u'crabilicious',
#  u'bagshaw',
#  u'kaya',
#  u'foutent',
#  u'siracha',
#  u'yeishi',
#  u'menudo',
#  u'committing',
#  u'weins',
#  u'object',
#  u'jaser',
#  u'dustbuster',
#  u'welll',
#  u'addict',
#  u'entry',
#  u'singer',
#  u'released',
#  u'camp',
#  u'memberships',
#  u'drunks',
#  u'marvel',
#  u'signatures',
#  u'sweetner',
#  u'loitered',
#  u'prix',
#  u'mcds',
#  u'participate',
#  u'heckled',
#  u'cheaply',
#  u'orleans',
#  u'touches',
#  u'skinnyfats',
#  u'reheating',
#  u'rico',
#  u'bliss',
#  u'foolishly',
#  u'galement',
#  u'chiladas',
#  u'klein',
#  u'honda',
#  u'foremost',
#  u'difara',
#  u'lenders',
#  u'altogether',
#  u'anxiolytic',
#  u'relish',
#  u'avenger',
#  u'saut',
#  u'greene',
#  u'saul',
#  u'sensitivity',
#  u'mamas',
#  u'clem',
#  u'bleh',
#  u'irv',
#  u'santos',
#  u'emptor',
#  u'nlich',
#  u'thevserver',
#  u'skimpy',
#  u'toilette',
#  u'sacrificing',
#  u'stuttgart',
#  u'logic',
#  u'tinge',
#  u'unbuttoned',
#  u'miscommunication',
#  u'advertisements',
#  u'kurma',
#  u'gleaming',
#  u'vais',
#  u'roofer',
#  u'rangers',
#  u'fro',
#  u'twain',
#  u'toning',
#  u'obese',
#  u'regaled',
#  u'cunt',
#  u'commerce',
#  u'contemplated',
#  u'professionally',
#  u'calcium',
#  u'elaborate',
#  u'remembering',
#  u'tzu',
#  u'saltiness',
#  u'characterize',
#  u'doorman',
#  u'portobella',
#  u'toaster',
#  u'oozed',
#  u'craigslist',
#  u'effortlessly',
#  u'bib',
#  u'suppen',
#  u'photographers',
#  u'symmetrical',
#  u'attendais',
#  u'tune',
#  u'maximizing',
#  u'acoustics',
#  u'echoed',
#  u'plaque',
#  u'kilts',
#  u'tilde',
#  u'lassi',
#  u'spectacles',
#  u'emphasis',
#  u'hag',
#  u'vendeurs',
#  u'survival',
#  u'unequivocally',
#  u'rocket',
#  u'otherworldly',
#  u'firmed',
#  u'aussenstehenden',
#  u'tapering',
#  u'bobby',
#  u'froide',
#  u'cambod',
#  u'meisten',
#  u'battlefield',
#  u'crown',
#  u'harassment',
#  u'rotisserie',
#  u'allesamt',
#  u'creep',
#  u'fox',
#  u'witty',
#  u'foe',
#  u'fog',
#  u'indication',
#  u'mildewed',
#  u'picerie',
#  u'binder',
#  u'substituted',
#  u'shifting',
#  u'visitng',
#  u'filipino',
#  u'boiling',
#  u'coronado',
#  u'reathrey',
#  u'statements',
#  u'administer',
#  u'moonen',
#  u'panorama',
#  u'solicitors',
#  u'avail',
#  u'joseph',
#  u'hothead',
#  u'shitiest',
#  u'jang',
#  u'rique',
#  u'underestimated',
#  u'forming',
#  u'notifications',
#  u'verde',
#  u'leider',
#  u'reinventing',
#  u'caromed',
#  u'handily',
#  u'azz',
#  u'refillable',
#  u'brimley',
#  u'moderne',
#  u'minibar',
#  u'regurgitating',
#  u'triangles',
#  u'microwaving',
#  u'actor',
#  u'grammatical',
#  u'truffles',
#  u'hawked',
#  u'outage',
#  u'devon',
#  u'adrianne',
#  u'labbie',
#  u'steelhead',
#  u'irrigation',
#  u'hangovers',
#  u'infants',
#  u'trashcan',
#  u'quartered',
#  u'landeskirche',
#  u'ballet',
#  u'flubbed',
#  u'ndisch',
#  u'bicycles',
#  u'floundering',
#  u'icing',
#  u'prepaid',
#  u'chainiest',
#  u'refinance',
#  u'wharton',
#  u'bustle',
#  u'teas',
#  u'curd',
#  u'skewed',
#  u'settle',
#  u'spiritual',
#  u'rentr',
#  u'boca',
#  u'bagging',
#  u'educate',
#  u'tartare',
#  u'takashi',
#  u'dictates',
#  u'contemplate',
#  u'crumbles',
#  u'brilliant',
#  u'rockbot',
#  u'cette',
#  u'commonly',
#  u'queue',
#  u'accomplished',
#  u'crumbled',
#  u'bearable',
#  u'tasks',
#  u'barbers',
#  u'papas',
#  u'explicitly',
#  u'films',
#  u'ivonne',
#  u'absolument',
#  u'scratches',
#  u'valued',
#  u'believer',
#  u'strain',
#  u'harmonious',
#  u'values',
#  u'fandango',
#  u'mirrors',
#  u'listend',
#  u'cwru',
#  u'nascar',
#  u'matzo',
#  u'monitoring',
#  u'buttered',
#  u'agave',
#  u'elephant',
#  u'grossed',
#  u'loathe',
#  u'mignons',
#  u'provincial',
#  u'lids',
#  u'egotistical',
#  u'insulated',
#  u'sofort',
#  u'sp',
#  u'sw',
#  u'si',
#  u'sm',
#  u'swollen',
#  u'episodes',
#  u'tendency',
#  u'splurge',
#  u'disconnect',
#  u'accordion',
#  u'milked',
#  u'cleanest',
#  u'toro',
#  u'faves',
#  u'decreased',
#  u'petition',
#  u'instantly',
#  u'modestly',
#  u'lvac',
#  u'maintaining',
#  u'matched',
#  u'shouted',
#  u'hickory',
#  u'phenomenally',
#  u'veins',
#  u'salado',
#  u'retrieve',
#  u'becauase',
#  u'impolite',
#  u'smelliness',
#  u'sexually',
#  u'troll',
#  u'overworked',
#  u'canvas',
#  u'rounding',
#  u'squared',
#  u'astray',
#  u'linguini',
#  u'suggesting',
#  u'stonecrest',
#  u'squares',
#  u'linguine',
#  u'huevos',
#  u'grandma',
#  u'bumpy',
#  u'quits',
#  u'homeopathic',
#  u'remainder',
#  u'dunno',
#  u'modest',
#  u'initiate',
#  u'livable',
#  u'bothersome',
#  u'routes',
#  u'router',
#  u'neglect',
#  u'intuition',
#  u'hashbrown',
#  u'tableaux',
#  u'reopen',
#  u'spokes',
#  u'vote',
#  u'ons',
#  u'barbacoa',
#  u'urig',
#  u'strawbz',
#  u'realization',
#  u'shoppers',
#  u'lingering',
#  u'shawn',
#  u'illusionist',
#  u'southbound',
#  u'padding',
#  u'bored',
#  u'iceberg',
#  u'plein',
#  u'nemanic',
#  u'recieved',
#  u'prospect',
#  u'noggins',
#  u'sal',
#  u'greyhound',
#  u'taster',
#  u'tastey',
#  u'allem',
#  u'sav',
#  u'sau',
#  u'pimply',
#  u'fashionable',
#  u'glimmers',
#  u'goodman',
#  u'printer',
#  u'buffer',
#  u'blowers',
#  u'terroir',
#  u'lawn',
#  u'peice',
#  u'spirulina',
#  u'touchy',
#  u'archy',
#  u'montagu',
#  u'accented',
#  u'usualy',
#  u'bereits',
#  u'flattizzas',
#  u'slot',
#  u'weapons',
#  u'unkind',
#  u'gourd',
#  u'meilleur',
#  u'pothole',
#  u'molinar',
#  u'psychiatrist',
#  u'freezing',
#  u'herbal',
#  u'dasselbe',
#  u'ux',
#  u'hinges',
#  u'bumpers',
#  u'scotch',
#  u'priest',
#  u'primp',
#  u'worries',
#  u'bombz',
#  u'espn',
#  u'masseur',
#  u'psych',
#  u'americanized',
#  u'hergestellt',
#  u'divey',
#  u'impressions',
#  u'liebsten',
#  u'mecca',
#  u'poops',
#  u'compounds',
#  u'harvey',
#  u'goers',
#  u'inappropriately',
#  u'cantaloupe',
#  u'checkered',
#  u'apiece',
#  u'dome',
#  u'supermarket',
#  u'horriably',
#  u'geschmack',
#  u'uncharacteristically',
#  u'concentrated',
#  u'tastless',
#  u'carwashed',
#  u'thickly',
#  u'deduction',
#  u'paring',
#  u'plantains',
#  u'expression',
#  u'loveliest',
#  u'anti',
#  u'besoin',
#  u'receptionists',
#  u'cokes',
#  u'seulement',
#  u'teddy',
#  u'pfingstgemeinde',
#  u'demanding',
#  u'kinks',
#  u'lanes',
#  u'observe',
#  u'quadruple',
#  u'resturant',
#  u'canoes',
#  u'ovenbake',
#  u'engages',
#  u'fame',
#  u'laceration',
#  u'wiring',
#  u'surveillance',
#  u'coconuty',
#  u'wires',
#  u'deft',
#  u'ordred',
#  u'reverts',
#  u'tadka',
#  u'deff',
#  u'indikator',
#  u'mohawk',
#  u'vacant',
#  u'nothin',
#  u'morons',
#  u'stammklientel',
#  u'personaly',
#  u'fateful',
#  u'grounded',
#  u'jarred',
#  u'trajet',
#  u'marinate',
#  u'drippings',
#  u'optometrists',
#  u'sums',
#  u'breakage',
#  u'erstklassig',
#  u'vague',
#  u'partaking',
#  u'crostini',
#  u'schools',
#  u'pole',
#  u'preference',
#  u'deviate',
#  u'scurrying',
#  u'beverly',
#  u'claw',
#  u'scamming',
#  u'arrested',
#  u'tvs',
#  u'serranos',
#  u'racial',
#  u'oomyang',
#  u'jgh',
#  u'montelaro',
#  u'tubs',
#  u'unsuccessfully',
#  u'biased',
#  u'malfunctioning',
#  u'stroganoff',
#  u'graal',
#  u'legged',
#  u'cowhide',
#  u'purplish',
#  u'bubbly',
#  u'punished',
#  u'hen',
#  u'bubble',
#  u'survives',
#  u'recommends',
#  u'yayy',
#  u'botta',
#  u'bundt',
#  u'survived',
#  u'technologies',
#  u'yumny',
#  u'abused',
#  u'naming',
#  u'monopoly',
#  u'flirt',
#  u'ragu',
#  u'politically',
#  u'rust',
#  u'darker',
#  u'interactive',
#  u'hoodlum',
#  u'yummmy',
#  u'unwelcomed',
#  u'maloof',
#  u'spinball',
#  u'passerby',
#  u'gourmandise',
#  u'crinkle',
#  u'accosted',
#  u'etwas',
#  u'terry',
#  u'resell',
#  u'snagged',
#  u'neuter',
#  u'cpa',
#  u'johnjay',
#  u'fraudulent',
#  u'pleassse',
#  u'tours',
#  u'upkeep',
#  u'reasoning',
#  u'ombr',
#  u'ty',
#  u'dsl',
#  u'tl',
#  u'chewing',
#  u'te',
#  u'norm',
#  u'puzzles',
#  u'salesperson',
#  u'hooking',
#  u'shenanigans',
#  u'misinformation',
#  u'laud',
#  u'mammal',
#  u'maggie',
#  u'quicker',
#  u'substitutions',
#  u'gerichte',
#  u'anywho',
#  u'fucks',
#  u'prevailed',
#  u'tanya',
#  u'contrast',
#  u'vomiting',
#  u'november',
#  u'wellfare',
#  u'truvape',
#  u'durch',
#  u'skepticism',
#  u'aufh',
#  u'vig',
#  u'vid',
#  u'vie',
#  u'arrivage',
#  u'vin',
#  u'etwist',
#  u'pulls',
#  u'sensors',
#  u'select',
#  u'attendance',
#  u'britannia',
#  u'pears',
#  u'pearl',
#  u'jjambbongs',
#  u'teen',
#  u'substances',
#  u'cacd',
#  u'cult',
#  u'sizing',
#  u'thickest',
#  u'impacts',
#  u'disliked',
#  u'xxxx',
#  u'shipped',
#  u'dismissed',
#  u'glowing',
#  u'browns',
#  u'plant',
#  u'countryside',
#  u'soundtrack',
#  u'waves',
#  u'pleaded',
#  u'huddled',
#  u'snotty',
#  u'rowdy',
#  u'curmudgeon',
#  u'brim',
#  u'installer',
#  u'schoolhouse',
#  u'dieing',
#  u'rapidly',
#  u'buttercup',
#  u'ruining',
#  u'nifty',
#  u'travelling',
#  u'snobs',
#  u'aggitated',
#  u'buffering',
#  u'gestaltung',
#  u'troubleshoot',
#  u'nauseous',
#  u'abadoba',
#  u'piping',
#  u'brunette',
#  u'england',
#  u'reduce',
#  u'grandmothers',
#  u'garners',
#  u'bouquets',
#  u'tahiti',
#  u'terrify',
#  u'ernie',
#  u'scoops',
#  u'mattered',
#  u'fte',
#  u'bestellt',
#  u'egypt',
#  u'attentions',
#  u'teppanyaki',
#  u'belief',
#  u'risen',
#  u'porcelain',
#  u'sparked',
#  u'olds',
#  u'fatass',
#  u'mlife',
#  u'exhibited',
#  u'arose',
#  u'dolmas',
#  u'guac',
#  u'contender',
#  u'preservation',
#  u'kobe',
#  u'glitter',
#  u'unpleased',
#  u'hots',
#  u'kuchen',
#  u'bigscreen',
#  u'speil',
#  u'noms',
#  u'ripofff',
#  u'calculations',
#  u'jen',
#  u'grace',
#  u'obama',
#  u'tortellini',
#  u'observatory',
#  u'kreme',
#  u'vocal',
#  u'acrobats',
#  u'remembers',
#  u'bavarian',
#  u'odors',
#  u'fermented',
#  u'nutshell',
#  u'extorted',
#  u'motto',
#  u'brace',
#  u'tryst',
#  u'sauerkraut',
#  u'galway',
#  u'slick',
#  u'artistic',
#  u'gabi',
#  u'barren',
#  u'gabe',
#  u'attacking',
#  u'despise',
#  u'ugg',
#  u'moroccan',
#  u'crois',
#  u'hadnt',
#  u'burrata',
#  u'impact',
#  u'indicator',
#  u'writes',
#  u'gooey',
#  u'condom',
#  u'factor',
#  u'thennnnn',
#  u'magicians',
#  u'maddios',
#  u'sunni',
#  u'approaching',
#  u'bozo',
#  u'mcccd',
#  u'nibble',
#  u'sex',
#  u'collectively',
#  u'microchipping',
#  u'cappy',
#  u'ritz',
#  u'oishi',
#  u'candor',
#  u'bizmark',
#  u'arises',
#  u'fidgets',
#  u'untouched',
#  u'spiget',
#  u'retarded',
#  u'lasi',
#  u'lanyard',
#  u'soyrizo',
#  u'brigla',
#  u'devil',
#  u'meinholz',
#  u'schenkt',
#  u'proprietor',
#  u'extravagant',
#  u'resting',
#  u'pirogies',
#  u'awake',
#  u'traumatizing',
#  u'frits',
#  u'packers',
#  u'slobs',
#  u'disrupt',
#  u'expanded',
#  u'nanas',
#  u'leaning',
#  u'moth',
#  u'titanic',
#  u'vow',
#  u'audi',
#  ...]

# %%
len(stop_words_list_max)
# Out:
# 5935

# %%
np.savetxt('stopwords.txt', stop_words_list_max, delimiter = ',', fmt="%s", newline = ' ')

# %%
vec_max = CountVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, 
                          token_pattern = u"(?u)\\b\\w+\\b", 
                          stop_words = stop_words_list_max, max_features = 100000) 
train_data_features_max = vec_max.fit_transform(df['clean_text'])
sum_words_max = train_data_features_max.sum(axis = 0)
words_freq_max = [(word, sum_words_max[0, idx]) for word, idx in vec_max.vocabulary_.items()]
words_freq_max = sorted(words_freq_max, key = lambda x: x[1], reverse =True)
words_max = pd.DataFrame(words_freq_max, columns = ['word', 'count'])
words_max['word_rank'] = words_max['count'].rank(ascending = False)
words_max.head()
# Out:
#          word  count  word_rank
# 0         now    250        1.0
# 1        want    249        2.0
# 2      called    247        3.0
# 3  definitely    246        4.0
# 4        work    243        5.0

# %%
plt.figure(figsize=(8, 6))
plt.plot(words_max['word_rank'], words_max['count'], color='g', linestyle='dashed', 
         marker = 'o',linewidth=2,alpha=0.5)
plt.xlabel('Word Rank')
plt.ylabel('Word count')
plt.title('Word counts vs word rank after stop words with max_freq = 250 min_freq = 1')
plt.grid()

# %%
##threshold = 50
stop_words_list_min = words['word'][words['count'] > 50].values.tolist()
vec_min = CountVectorizer(analyzer = "word", tokenizer = None, preprocessor = None, 
                          token_pattern = u"(?u)\\b\\w+\\b", 
                          stop_words = stop_words_list_min, max_features = 100000) 
train_data_features_min = vec_min.fit_transform(df['clean_text'])
sum_words_min = train_data_features_min.sum(axis = 0)
words_freq_min = [(word, sum_words_min[0, idx]) for word, idx in vec_min.vocabulary_.items()]
words_freq_min = sorted(words_freq_min, key = lambda x: x[1], reverse =True)
words_min = pd.DataFrame(words_freq_min, columns = ['word', 'count'])
words_min['word_rank'] = words_min['count'].rank(ascending = False)
plt.figure(figsize=(8, 6))
plt.plot(words_min['word_rank'], words_min['count'], color='g', 
         linestyle='dashed', marker = 'o',linewidth=2,alpha=0.5)
plt.xlabel('Word Rank')
plt.ylabel('Word count')
plt.title('Word counts vs word rank after stop words with min_freq = 50')
plt.grid()

# %%
#stop_words_list_min
len(stop_words_list_min)
# Out:
# 561

# %% [markdown]
# Set threshold = 250

# %% [markdown]
# Part 2 use max frequency

# %%
#from sklearn.metrics.pairwise import cosine_similarity
max_array = train_data_features_max.toarray() ##bag_of_words threshold = 250
query = vec_max.transform(['Horrible customer service']).toarray()

# %%
def cos_distance(a, b):
    return 1.0 * np.dot(a, b.T) / (np.linalg.norm(a) * np.linalg.norm(b))
cos_sim = np.zeros(2000,)
for i in range(2000):
    cos_sim[i] = cos_distance(max_array[i], query)

# %%
df['cosim'] = cos_sim
df_disc = df.sort_values(by = ['cosim'], ascending = False)
for i in range(5):
    text = df_disc.iloc[i]['text']
    dis = df_disc.iloc[i]['cosim']
    print(text + '\n' + 'cosine distance score: ' + str(dis) +'\n')
# Out:
# Service was horrible came with a major attitude. Payed 30 for lasagna and was no where worth it. Won't ever be going back and will NEVER recommend this place. was treated absolutely horrible. Horrible.
# cosine distance score: 0.6882472016116852
#
# HORRIBLE HORRIBLE HORRIBLE!!! AVOID AT ALL COSTS!!!
#
# I had some work done at Swing Shift Auto and I was helped by Keith. He was very arrogant and had little time for me. I just needed new brake discs and pads. I was overcharged, the repairs took TWO DAYS, and when I got home i noticed that the discs had NOT been replaced, only the pads!!!!
#
# TOTAL RIPOFFF!!! NEVER GO HERE, PLEASE!!!
# cosine distance score: 0.48038446141526137
#
# Horrible service, horrible customer service, and horrible quality of service!  Do not waste your time or money using this company for your pool needs.  Dan (602)363-8267 broke my pool filtration system and left it in a nonworking condition.  He will not repair the issue he caused, and told me to go somewhere else.
#
# Save yourself the hassle, there are plenty of other quality pool companies out there.
#
# Take care!
# cosine distance score: 0.45226701686664544
#
# I was in there a few weeks ago, the lady who took my order DENE was horrible....not only did she give me the wrong change but had a terrible attitude and also put in my order wrong not to mention it looked as if she was hungover
# If I could give this a negative star I would...what a horrible representation of this place
# cosine distance score: 0.42640143271122083
#
# Horrible experience! Got there at 1 am and the front desk worker wasn't there. The lights were turned off so I called with the after hours phone. After 10 minutes, someone let us in and we stood at the counter and he finally walked up, then told us we couldn't check in for an hour because the computer was down. Finally got to our room 2 hours later! Horrible experience!
# cosine distance score: 0.35355339059327373

# %%
len(df_disc['cosim'][df_disc['cosim'] >= 0.15])
# Out:
# 54

# %%
df_disc[:60]
# Out:
#                                                    text  stars  \
# 729   Service was horrible came with a major attitud...      1
# 479   HORRIBLE HORRIBLE HORRIBLE!!! AVOID AT ALL COS...      1
# 90    Horrible service, horrible customer service, a...      1
# 1961  I was in there a few weeks ago, the lady who t...      1
# 1763  Horrible experience! Got there at 1 am and the...      1
# 1840  Horrible service....What a mess upon ordering ...      1
# 1354  The food is okay but the service is horrible. ...      1
# 1131  I don't understand how people pay money to eat...      1
# 1842  Horrible service! Food was not great either. O...      1
# 866   They have no concept of making an authentic sh...      1
# 1808  Rogers ...\n\n1) is over priced\n2) have horri...      1
# 887   Horrible service. I was treated so poorly by t...      1
# 1646  Would give this place negative stars if I coul...      1
# 1110  This place is horrible. I ask the guy to make ...      1
# 1764  Ok. So food is alright. But the service was ho...      1
# 335   All of the staff here were so kind to me and m...      5
# 787   Horrible. Worst service ever.  Waitstaff was l...      1
# 446   Service was ok, food was horrible and there ar...      1
# 1373  This buffet sucks. Horrible variety, no sides,...      1
# 1032  Horrible service! I walked in with two bags an...      1
# 1465  Payless Rent-A-Car is the most horrible place ...      1
# 1520  HORRIBLE customer service. When you call you'l...      1
# 1723  The service is horrible. It's not bad inside, ...      1
# 838   Horrible snobby service. Took forever. Just wa...      1
# 1335  Horrible attorney.  Defend yourself before hir...      1
# 55    Walmart pick up was really horrible.\nI receiv...      1
# 161   Used to love this place but recently had the w...      1
# 342   everytime we go to this Dennys we have nothing...      1
# 1669  Horrible service! Tried to reservation, I was ...      1
# 651   Horrible service and the food is just as bad. ...      1
# 279   Horrible. Absolutely horrible. Seems like they...      1
# 642   Horrible horrible place! I don't understand wh...      1
# 1403  I was just telling my family about this place ...      1
# 1114  Thanks for making my shity Monday more shity. ...      1
# 881   The guy who gave me a massage smelled like cig...      1
# 1342  The worst dog grooming I have ever had stay aw...      1
# 73    Thanksgiving buffet horrible 64$ for some frie...      1
# 1784  I will never go back to this bar or invite any...      1
# 883   Wish I could give it negative stars\n\nUnbelie...      1
# 9     Horrible customer service!  Been with them ove...      1
# 1852  Horrible please do not go here I went here las...      1
# 732   Wow this food was really horrible. All meats w...      1
# 1930  I used to love this place, but NEVER order fro...      1
# 577   Zollie is still not cooperating nor helping to...      1
# 1169  I waited about a week to write this review to ...      1
# 1793  Possibly the worst Japanese AYCE I have ever b...      1
# 72    For a place that has been in business for year...      1
# 801   I have been here multiple times with my friend...      1
# 253   Absolutely horrible first experience. Ordered ...      1
# 340   Went in to return an item the greeter was frie...      1
# 1705  The menu is extremely limited and the service ...      1
# 652   I also wish I could give them zero stars. \n\n...      1
# 1201  Eat here at your own risk.  This place is horr...      1
# 245   Worst hotel in Vegas, I'd rather sleep in my c...      1
# 983   Horrible experience!! Beware using this compan...      1
# 32    Horrible experience and most awful customer se...      1
# 1240  I would give it -2 stars. I was waiting for my...      1
# 448   I went into this location because my sister ha...      1
# 1371  Horrible so far we booked two nights in the Pa...      1
# 1379  Service is horrible. I have specific dietary n...      1
#
#                                              clean_text     cosim
# 729   Service was horrible came with a major attitud...  0.688247
# 479   HORRIBLE HORRIBLE HORRIBLE    AVOID AT ALL COS...  0.480384
# 90    Horrible service  horrible customer service  a...  0.452267
# 1961  I was in there a few weeks ago  the lady who t...  0.426401
# 1763  Horrible experience  Got there at   am and the...  0.353553
# 1840  Horrible service    What a mess upon ordering ...  0.333333
# 1354  The food is okay but the service is horrible  ...  0.333333
# 1131  I don t understand how people pay money to eat...  0.324443
# 1842  Horrible service  Food was not great either  O...  0.316228
# 866   They have no concept of making an authentic sh...  0.316228
# 1808  Rogers         is over priced    have horrible...  0.316228
# 887   Horrible service  I was treated so poorly by t...  0.316228
# 1646  Would give this place negative stars if I coul...  0.316228
# 1110  This place is horrible  I ask the guy to make ...  0.316228
# 1764  Ok  So food is alright  But the service was ho...  0.301511
# 335   All of the staff here were so kind to me and m...  0.288675
# 787   Horrible  Worst service ever   Waitstaff was l...  0.288675
# 446   Service was ok  food was horrible and there ar...  0.288675
# 1373  This buffet sucks  Horrible variety  no sides ...  0.277350
# 1032  Horrible service  I walked in with two bags an...  0.277350
# 1465  Payless Rent A Car is the most horrible place ...  0.274075
# 1520  HORRIBLE customer service  When you call you l...  0.267261
# 1723  The service is horrible  It s not bad inside  ...  0.267261
# 838   Horrible snobby service  Took forever  Just wa...  0.258199
# 1335  Horrible attorney   Defend yourself before hir...  0.250000
# 55    Walmart pick up was really horrible  I receive...  0.242536
# 161   Used to love this place but recently had the w...  0.242536
# 342   everytime we go to this Dennys we have nothing...  0.235702
# 1669  Horrible service  Tried to reservation  I was ...  0.235702
# 651   Horrible service and the food is just as bad  ...  0.229416
# 279   Horrible  Absolutely horrible  Seems like they...  0.227921
# 642   Horrible horrible place  I don t understand wh...  0.226455
# 1403  I was just telling my family about this place ...  0.213201
# 1114  Thanks for making my shity Monday more shity  ...  0.213201
# 881   The guy who gave me a massage smelled like cig...  0.208514
# 1342  The worst dog grooming I have ever had stay aw...  0.204124
# 73    Thanksgiving buffet horrible     for some frie...  0.200000
# 1784  I will never go back to this bar or invite any...  0.200000
# 883   Wish I could give it negative stars  Unbelieva...  0.196116
# 9     Horrible customer service   Been with them ove...  0.192450
# 1852  Horrible please do not go here I went here las...  0.188982
# 732   Wow this food was really horrible  All meats w...  0.188982
# 1930  I used to love this place  but NEVER order fro...  0.185695
# 577   Zollie is still not cooperating nor helping to...  0.179605
# 1169  I waited about a week to write this review to ...  0.178647
# 1793  Possibly the worst Japanese AYCE I have ever b...  0.174667
# 72    For a place that has been in business for year...  0.174078
# 801   I have been here multiple times with my friend...  0.171499
# 253   Absolutely horrible first experience  Ordered ...  0.164399
# 340   Went in to return an item the greeter was frie...  0.162221
# 1705  The menu is extremely limited and the service ...  0.160128
# 652   I also wish I could give them zero stars    Pl...  0.158114
# 1201  Eat here at your own risk   This place is horr...  0.156174
# 245   Worst hotel in Vegas  I d rather sleep in my c...  0.154303
# 983   Horrible experience   Beware using this compan...  0.149071
# 32    Horrible experience and most awful customer se...  0.147442
# 1240  I would give it    stars  I was waiting for my...  0.141421
# 448   I went into this location because my sister ha...  0.139010
# 1371  Horrible so far we booked two nights in the Pa...  0.136083
# 1379  Service is horrible  I have specific dietary n...  0.134840

# %%
len(df_disc['cosim'][df_disc['cosim'] >= 0.15])
# Out:
# 54

# %% [markdown]
# Part 3 Logistic regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
X_train, X_test, y_train, y_test = train_test_split(train_data_features_max, df['stars'], 
                                                    test_size = 0.1, random_state = 42)

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(class_weight = 'balanced')
logreg.fit(X_train, y_train)
threshold = 0.5
predicts = np.where(logreg.predict_proba(X_test)[:, 1] > threshold, 5, 1)

# %%
accuracy_score(np.where(logreg.predict_proba(X_train)[:, 1] > threshold, 5, 1), y_train)  
###train set accuracy score
# Out:
# 0.9994444444444445

# %%
accuracy_score(predicts, y_test) ###test set accuracy score
# Out:
# 0.92

# %% [markdown]
# Plot histogram of scores on training data

# %%
pos_score = logreg.predict_proba(X_train)[:, 1][np.where(logreg.predict_proba(X_train)[:, 1] > threshold)]
neg_score = logreg.predict_proba(X_train)[:, 0][np.where(logreg.predict_proba(X_train)[:, 0] <= threshold)]

# %%
pos_train = logreg.predict_proba(X_train)[:, 1][np.where(y_train[logreg.predict_proba(X_train)[:, 1] > threshold]== 5)]
neg_train = logreg.predict_proba(X_train)[:, 0][np.where(y_train[logreg.predict_proba(X_train)[:, 1] <= threshold]== 1)]

# %%
plt.hist(pos_train, bins = 100, color = 'g', alpha = 0.5, density = False, rwidth = 0.9, label = 'positive score')
plt.hist(neg_train, bins = 100, color = 'b', alpha = 0.5, density = False, rwidth = 0.9, label = 'negative score')
plt.xlim(0, 1.0)
plt.xlabel('Predicted score')
plt.ylabel('Count of predictions')
plt.title('Histogram of Predicted Scores')
plt.legend(loc = 'center')
plt.show()

# %%
pos_train_true = logreg.predict_proba(X_train)[:, 1][np.where(y_train[logreg.predict_proba(X_train)[:, 1] > threshold]== 5)]
pos_train_neg = logreg.predict_proba(X_train)[:, 1][np.where(y_train[logreg.predict_proba(X_train)[:, 1] > threshold]== 1)]
plt.hist(pos_train_true, bins = 100, color = 'g', alpha = 0.5, density = False, rwidth = 0.9, label = 'true')
plt.hist(pos_train_neg, bins = 100, color = 'b', alpha = 0.5, density = False, rwidth = 0.9, label = 'negative')
plt.xlim(0, 1.0)
plt.xlabel('Predicted score')
plt.ylabel('Count of predictions')
plt.title('Histogram of Predicted Scores for 5-star class')
plt.legend(loc = 'center')
plt.show()

# %%
neg_train_true = logreg.predict_proba(X_train)[:, 0][np.where(y_train[logreg.predict_proba(X_train)[:, 1] <= threshold]== 1)]
neg_train_neg = logreg.predict_proba(X_train)[:, 0][np.where(y_train[logreg.predict_proba(X_train)[:, 1] <= threshold]== 5)]
plt.hist(neg_train_true, bins = 100, color = 'g', alpha = 0.5, density = False, rwidth = 0.9, label = 'true')
plt.hist(neg_train_neg, bins = 100, color = 'b', alpha = 0.5, density = False, rwidth = 0.9, label = 'negative')
plt.xlim(0, 1.0)
plt.xlabel('Predicted score')
plt.ylabel('Count of predictions')
plt.title('Histogram of Predicted Scores for 1-star class')
plt.legend(loc = 'center')
plt.show()

# %%
import seaborn as sns
sns.distplot(pos_score, color = 'g', label = 'positive score')
sns.distplot(neg_score, color = 'b', label = 'negative score')
plt.xlim(-0.05, 1.05)
plt.xlabel('Predicted score')
plt.ylabel('Count of predictions')
plt.title('Histogram of Predicted Scores')
plt.legend(loc = 'center')
plt.show()

# %%
plt.hist(pos_score, bins = 100, color = 'g', alpha = 0.5, density = False, rwidth = 0.9, label = 'positive score')
plt.hist(neg_score, bins = 100, color = 'b', alpha = 0.5, density = False, rwidth = 0.9, label = 'negative score')
plt.xlim(0, 1.0)
plt.xlabel('Predicted score')
plt.ylabel('Count of predictions')
plt.title('Histogram of Predicted Scores')
plt.legend(loc = 'center')
plt.show()

# %%
threshold_n = 0.4
predicts_n = np.where(logreg.predict_proba(X_test)[:, 1] > threshold_n, 5, 1)
accuracy_score(np.where(logreg.predict_proba(X_train)[:, 1] > threshold_n, 5, 1), y_train)  
###train set accuracy score
# Out:
# 0.9983333333333333

# %%
accuracy_score(predicts_n, y_test) ###test set accuracy score
# Out:
# 0.93

# %%
from sklearn.metrics import roc_curve, auc
y_scores = logreg.decision_function(X_test)
fpr, tpr, _ = roc_curve(y_test, y_scores, pos_label = 5)
plt.plot(fpr, tpr, linewidth = 2, color = 'darkorange', label = 'ROC curve (area = %0.2f)' % auc(fpr, tpr))
plt.plot([0, 1], [0, 1], 'k--')
plt.axis([-0.005, 1.015, 0, 1.015])
plt.xticks(np.arange(0, 1.25, 0.25))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc = 'lower right')

# %%
fpr[np.argmax(tpr)]
# Out:
# 0.22448979591836735

# %%
test = np.arange(0.1, 1.0, 0.1)
train_score = []
test_score = []
for i in test:
    predicts = np.where(logreg.predict_proba(X_test)[:, 1] > i, 5, 1)
    train_score.append(accuracy_score(np.where(logreg.predict_proba(X_train)[:, 1] > i, 5, 1), y_train))  
    ###train set accuracy score
    test_score.append(accuracy_score(predicts, y_test)) ###test set accuracy score

# %%
train_score, test_score
# Out:
# ([0.9344444444444444,
#   0.985,
#   0.9955555555555555,
#   0.9983333333333333,
#   0.9994444444444445,
#   1.0,
#   0.9977777777777778,
#   0.9905555555555555,
#   0.94],
#  [0.86, 0.885, 0.915, 0.93, 0.92, 0.895, 0.89, 0.86, 0.795])
